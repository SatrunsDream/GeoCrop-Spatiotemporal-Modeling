# %% [markdown]
# # Task 1 — Notebook 05: Report Export & Run Bundle
#
# **Purpose:** Compile final Task 1 outputs into a run bundle.
# Write `meta.json`, `metrics.json`, `outputs.json`, and `notes.md` to `artifacts/logs/runs/`.
# Update `structure.md` artifact index.
#
# **Inputs:** All Task 1 processed outputs and figures.
#
# **Outputs:**
# - `artifacts/logs/runs/<run_id>/meta.json`
# - `artifacts/logs/runs/<run_id>/metrics.json`
# - `artifacts/logs/runs/<run_id>/outputs.json`
# - `artifacts/logs/runs/<run_id>/notes.md`

# %%
# NOTE: This notebook was scaffolded with AI assistance.

import json, yaml, sys
from datetime import datetime
from pathlib import Path

REPO_ROOT = Path().resolve().parents[1]
sys.path.insert(0, str(REPO_ROOT))

# %%
# TODO: Generate run_id: YYYY-MM-DD__HHMM__task1_ndvi__<git_sha>
# TODO: Write meta.json (timestamp, config snapshot, git hash)
# TODO: Write metrics.json (key phenometric differences: corn vs. soy peak DOY, amplitude, etc.)
# TODO: Write outputs.json (paths to all figures and processed files)
# TODO: Write notes.md (short narrative: what was found, phenological interpretation)
