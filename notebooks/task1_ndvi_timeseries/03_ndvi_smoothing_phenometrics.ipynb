# %% [markdown]
# # Task 1 — Notebook 03: NDVI Smoothing & Phenometric Extraction
#
# **Purpose:** Apply time-series smoothing (Whittaker or SG) to trusted-pixel NDVI for corn and soybean.
# Extract phenometrics: greenup DOY, peak DOY, senescence DOY, amplitude, integral, slope rates.
#
# **Inputs:**
# - `data/interim/task1_ndvi_masked_corn.nc`
# - `data/interim/task1_ndvi_masked_soy.nc`
#
# **Outputs:**
# - `data/processed/task1/corn_phenometrics.parquet`
# - `data/processed/task1/soy_phenometrics.parquet`
# - `data/processed/task1/corn_smoothed_ndvi.nc`
# - `data/processed/task1/soy_smoothed_ndvi.nc`

# %%
# NOTE: This notebook was scaffolded with AI assistance.

import yaml, sys
from pathlib import Path

REPO_ROOT = Path().resolve().parents[1]
sys.path.insert(0, str(REPO_ROOT))

with open(REPO_ROOT / 'configs' / 'task1_ndvi_analysis.yaml') as f:
    cfg = yaml.safe_load(f)

# %%
# TODO: Load masked NDVI for corn and soy
# TODO: Apply smoothing via src.preprocessing.ndvi_smoothing.smooth()
#   method = cfg['smoothing']['method']  (whittaker | savitzky_golay | ...)

# %%
# TODO: Extract phenometrics per pixel using src.modeling.phenology_fitting
# TODO: Compute mean + IQR across pixels for each crop type
# TODO: Save phenometrics DataFrames to data/processed/task1/
