# %% [markdown]
# # Task 1 — Notebook 04: Phenological Curve Visualization
#
# **Purpose:** Produce the key Task 1 deliverable figure — seasonal NDVI profiles for corn vs. soybean
# with IQR uncertainty bands and annotated phenological stages (planting, greenup, peak, harvest).
# Export figure to `artifacts/figures/task1/`.
#
# **Inputs:**
# - `data/processed/task1/corn_smoothed_ndvi.nc`
# - `data/processed/task1/soy_smoothed_ndvi.nc`
# - `data/processed/task1/corn_phenometrics.parquet`
# - `data/processed/task1/soy_phenometrics.parquet`
#
# **Outputs:**
# - `artifacts/figures/task1/task1__ndvi_phenology_corn_vs_soy__<date>.png`
# - `artifacts/tables/task1/task1__phenometrics_summary__<date>.csv`

# %%
# NOTE: This notebook was scaffolded with AI assistance.

import yaml, sys
from pathlib import Path

REPO_ROOT = Path().resolve().parents[1]
sys.path.insert(0, str(REPO_ROOT))

with open(REPO_ROOT / 'configs' / 'task1_ndvi_analysis.yaml') as f:
    cfg = yaml.safe_load(f)

# %%
# TODO: Load smoothed NDVI and phenometrics for both crops
# TODO: Compute median + IQR NDVI curves across pixels by DOY

# %%
# TODO: Plot phenological curves using src.viz.phenology_plots
# TODO: Annotate greenup, peak, senescence stages
# TODO: Save figure: artifacts/figures/task1/task1__ndvi_phenology_corn_vs_soy__YYYY-MM-DD.png
# TODO: Export phenometrics summary table to artifacts/tables/task1/
