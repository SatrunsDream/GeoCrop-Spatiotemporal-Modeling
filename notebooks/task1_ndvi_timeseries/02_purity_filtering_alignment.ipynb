# %% [markdown]
# # Task 1 — Notebook 02: Purity Filtering & Spatial Alignment
#
# **Purpose:** Compute crop-fraction purity at 250 m resolution from 30 m CDL.
# Retain only 'trusted pixels' (purity ≥ 0.80) for corn and soybean separately.
# Align filtered CDL mask with the NDVI grid.
#
# **Inputs:**
# - `data/interim/task1_cdl_study_area.tif`
# - `data/interim/task1_ndvi_qa_filtered.nc`
#
# **Outputs:**
# - `data/interim/task1_corn_trusted_mask.tif`
# - `data/interim/task1_soy_trusted_mask.tif`
# - `data/interim/task1_ndvi_masked_corn.nc`
# - `data/interim/task1_ndvi_masked_soy.nc`

# %%
# NOTE: This notebook was scaffolded with AI assistance.

import yaml, sys
from pathlib import Path

REPO_ROOT = Path().resolve().parents[1]
sys.path.insert(0, str(REPO_ROOT))

with open(REPO_ROOT / 'configs' / 'task1_ndvi_analysis.yaml') as f:
    cfg = yaml.safe_load(f)

# %%
# TODO: Load interim CDL and NDVI from notebook 01
# TODO: Compute crop fraction per 250m cell for corn (CDL=1) and soybean (CDL=5)
# from src.preprocessing.purity_filtering import compute_purity

# %%
# TODO: Apply purity threshold (cfg['purity_filtering']['threshold'])
# TODO: Mask NDVI time series with trusted-pixel masks for corn and soy
# TODO: Visualize purity distribution histogram
# TODO: Save masked outputs to data/interim/
