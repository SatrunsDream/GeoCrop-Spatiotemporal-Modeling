# %% [markdown]
# # Task 3 — Notebook 03: Anomaly Computation
#
# **Purpose:** Compute standardized soil moisture anomalies for the event window
# relative to the baseline climatology. Produce z-score and/or percentile-rank anomaly layers.
#
# **Inputs:**
# - `data/interim/task3_smap_event_stack.nc`
# - `data/processed/task3/smap_climatology_mean.nc`
# - `data/processed/task3/smap_climatology_std.nc`
#
# **Outputs:**
# - `data/processed/task3/smap_anomaly_zscore.nc`
# - `data/processed/task3/smap_anomaly_percentile.nc`

# %%
# NOTE: This notebook was scaffolded with AI assistance.

import yaml, sys
from pathlib import Path

REPO_ROOT = Path().resolve().parents[1]
sys.path.insert(0, str(REPO_ROOT))

with open(REPO_ROOT / 'configs' / 'task3_soil_moisture.yaml') as f:
    cfg = yaml.safe_load(f)

# %%
# TODO: anomaly = (x(t) - μ(week)) / σ(week) for z-score
# TODO: percentile_rank: rank x(t) within the empirical distribution for that week
# TODO: Apply CDL cropland mask (aggregated to 9 km) via area-weighted crop fraction
# TODO: Save anomaly NetCDF files
