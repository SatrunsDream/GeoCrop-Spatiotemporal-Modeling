# %% [markdown]
# # Task 3 — Notebook 05: Agricultural Impact Analysis & Run Bundle
#
# **Purpose:** Connect soil moisture anomalies to expected agricultural impacts.
# Identify crop-growing regions most severely affected (by CDL-masked anomaly statistics).
# Link observed moisture conditions to crop development stages. Write run bundle.
#
# **Inputs:**
# - `data/processed/task3/smap_anomaly_zscore.nc`
# - CDL cropland mask (aggregated)
#
# **Outputs:**
# - `artifacts/tables/task3/task3__anomaly_stats_by_crop_region__<date>.csv`
# - `artifacts/logs/runs/<run_id>/` — run bundle

# %%
# NOTE: This notebook was scaffolded with AI assistance.

import yaml, sys
from pathlib import Path

REPO_ROOT = Path().resolve().parents[1]
sys.path.insert(0, str(REPO_ROOT))

# %%
# TODO: Compute per-crop-type area-weighted anomaly statistics over event window
# TODO: Identify top-N most affected SMAP cells (highest absolute anomaly)
# TODO: Cross-reference anomaly timing with typical crop development calendar
#   (planting: May, greenup: June, peak: July-Aug, harvest: Sept-Oct)

# %%
# TODO: Export anomaly statistics table
# TODO: Write run bundle (meta.json, metrics.json, outputs.json, notes.md)
