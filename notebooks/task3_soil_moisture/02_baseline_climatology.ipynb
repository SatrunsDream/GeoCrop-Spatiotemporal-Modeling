# %% [markdown]
# # Task 3 — Notebook 02: Baseline Climatology
#
# **Purpose:** Compute multi-year DOY/week-of-year climatology (μ and σ) from the baseline period
# at each SMAP grid cell. Store climatology for anomaly computation in notebook 03.
#
# **Inputs:**
# - `data/interim/task3_smap_baseline_stack.nc`
#
# **Outputs:**
# - `data/processed/task3/smap_climatology_mean.nc`
# - `data/processed/task3/smap_climatology_std.nc`
# - `data/processed/task3/smap_climatology_percentiles.nc` (optional)

# %%
# NOTE: This notebook was scaffolded with AI assistance.

import yaml, sys
from pathlib import Path

REPO_ROOT = Path().resolve().parents[1]
sys.path.insert(0, str(REPO_ROOT))

with open(REPO_ROOT / 'configs' / 'task3_soil_moisture.yaml') as f:
    cfg = yaml.safe_load(f)

# %%
# TODO: Group baseline stack by week-of-year (or DOY)
# TODO: Compute mean (μ) and std (σ) per cell per week
# TODO: Optionally compute empirical percentile distributions
# TODO: Save climatology NetCDF files
