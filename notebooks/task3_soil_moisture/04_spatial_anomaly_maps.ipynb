# %% [markdown]
# # Task 3 — Notebook 04: Spatial Anomaly Maps
#
# **Purpose:** Produce the Task 3 deliverable figures — spatial maps of soil moisture anomalies
# at key time steps during the event window. Include time series of area-averaged anomalies
# over cropland regions.
#
# **Inputs:**
# - `data/processed/task3/smap_anomaly_zscore.nc`
# - `data/processed/task3/smap_anomaly_percentile.nc`
#
# **Outputs:**
# - `artifacts/figures/task3/task3__anomaly_map_<date_step>__<run_date>.png`
# - `artifacts/figures/task3/task3__anomaly_timeseries_cropland__<run_date>.png`

# %%
# NOTE: This notebook was scaffolded with AI assistance.

import yaml, sys
from pathlib import Path

REPO_ROOT = Path().resolve().parents[1]
sys.path.insert(0, str(REPO_ROOT))

# %%
# TODO: Select 3–4 representative time steps during event window
# TODO: Plot spatial anomaly maps with diverging colormap, state boundaries, scale bar
# from src.viz.anomaly_maps import plot_anomaly_map

# %%
# TODO: Compute area-averaged anomaly time series over CDL cropland pixels
# TODO: Plot time series with threshold lines (e.g., z < -1, z > +1)
# TODO: Save all figures to artifacts/figures/task3/
