# %% [markdown]
# # Task 4 — Notebook 05: Feature Importance & Ablation Study
#
# **Purpose:** Quantify the contribution of each feature group (CDL-only, +NDVI, +SMAP, full model)
# via ablation experiments. Extract SHAP values or permutation importance. Write run bundle.
#
# **Inputs:**
# - Feature matrices for each ablation variant
# - `artifacts/models/task4/crop_type_model.joblib`
#
# **Outputs:**
# - `artifacts/figures/task4/task4__feature_importance_shap__<date>.png`
# - `artifacts/tables/task4/task4__ablation_metrics__<date>.csv`
# - `artifacts/logs/runs/<run_id>/` — run bundle

# %%
# NOTE: This notebook was scaffolded with AI assistance.

import yaml, sys
from pathlib import Path

REPO_ROOT = Path().resolve().parents[1]
sys.path.insert(0, str(REPO_ROOT))

with open(REPO_ROOT / 'configs' / 'task4_crop_mapping.yaml') as f:
    cfg = yaml.safe_load(f)

# %%
# TODO: Run ablation: train separate models for each feature set in cfg['feature_importance']['ablations']
#   [cdl_only, cdl_plus_ndvi, cdl_plus_smap, cdl_plus_ndvi_plus_smap]
# TODO: Record OA and macro-F1 for each ablation variant
# TODO: Export ablation metrics table

# %%
# TODO: Compute SHAP values for full model using shap library
# TODO: Plot SHAP summary plot (beeswarm) — top 20 features
# TODO: Save figure and run bundle
