# %% [markdown]
# # Task 4 — Notebook 03: Model Training & Evaluation
#
# **Purpose:** Train LightGBM (or XGBoost) crop-type classifier on CDL-history + NDVI + SMAP features.
# Validate using temporal holdout (train 2013–2022 context → predict 2023).
# Report: overall accuracy, per-class F1, confusion matrix. Stratify by rotation regime.
#
# **Inputs:**
# - `data/processed/task4/feature_matrix_full.parquet`
#
# **Outputs:**
# - `artifacts/models/task4/crop_type_model.joblib`
# - `artifacts/tables/task4/task4__classification_metrics__<date>.csv`
# - `artifacts/figures/task4/task4__confusion_matrix__<date>.png`

# %%
# NOTE: This notebook was scaffolded with AI assistance.

import yaml, sys
from pathlib import Path

REPO_ROOT = Path().resolve().parents[1]
sys.path.insert(0, str(REPO_ROOT))

with open(REPO_ROOT / 'configs' / 'task4_crop_mapping.yaml') as f:
    cfg = yaml.safe_load(f)

# %%
# TODO: Split train/test by temporal holdout (train: rows where label_year < 2023)
# TODO: Train LightGBM with config hyperparameters (cfg['model']['hyperparameters'])
# TODO: Predict on 2023 holdout set

# %%
# TODO: Compute OA, per-class F1, confusion matrix using src.evaluation.classification_metrics
# TODO: Stratify metrics by rotation_regime (regular / monoculture / irregular)
# TODO: Save metrics table and confusion matrix figure
# TODO: Serialize trained model to artifacts/models/task4/
