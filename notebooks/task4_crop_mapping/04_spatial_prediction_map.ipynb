# %% [markdown]
# # Task 4 — Notebook 04: Spatial Prediction Map
#
# **Purpose:** Apply the trained model across the full study area to produce a spatial map
# of predicted crop types for the test year (2023). Compare with CDL 2023 ground truth.
#
# **Inputs:**
# - `artifacts/models/task4/crop_type_model.joblib`
# - Full feature matrix for all pixels in study area (2023 context)
#
# **Outputs:**
# - `data/processed/task4/predicted_crop_type_2023.tif`
# - `artifacts/figures/task4/task4__predicted_crop_map_2023__<date>.png`
# - `artifacts/figures/task4/task4__prediction_vs_cdl_comparison__<date>.png`

# %%
# NOTE: This notebook was scaffolded with AI assistance.

import yaml, sys
from pathlib import Path

REPO_ROOT = Path().resolve().parents[1]
sys.path.insert(0, str(REPO_ROOT))

# %%
# TODO: Load trained model
# TODO: Run prediction across all cropland pixels in study area
# TODO: Reconstruct spatial raster from predictions (GeoTIFF, EPSG:5070)

# %%
# TODO: Plot predicted crop type map with Cartopy — class colormap, legend, scale bar
# TODO: Side-by-side comparison with CDL 2023
# TODO: Save prediction GeoTIFF and figures
